# %%
import pandas as pd

# %%
covid_df = pd.read_csv('covid-chestxray-dataset/metadata.csv')
covid_df.head(1).T
# Out:
#                                                                         0
# patientid                                                               2
# offset                                                                0.0
# sex                                                                     M
# age                                                                  65.0
# finding                                          Pneumonia/Viral/COVID-19
# RT_PCR_positive                                                         Y
# survival                                                                Y
# intubated                                                               N
# intubation_present                                                      N
# went_icu                                                                N
# in_icu                                                                  N
# needed_supplemental_O2                                                  Y
# ...

# %%
nih_df = pd.read_csv('nih-chestxray-dataset/Data_Entry_2017.csv')
nih_df.head(1).T
# Out:
#                                             0
# Image Index                  00000001_000.png
# Finding Labels                   Cardiomegaly
# Follow-up #                                 0
# Patient ID                                  1
# Patient Age                                58
# Patient Gender                              M
# View Position                              PA
# OriginalImage[Width                      2682
# Height]                                  2749
# OriginalImagePixelSpacing[x             0.143
# y]                                      0.143
# Unnamed: 11                               NaN

# %%
nih_renamed_df = nih_df.rename(columns={
  'Finding Labels': 'finding',
  'Patient Age': 'age',
  'Patient Gender': 'sex',
  'Patient ID': 'patientid',
  'View Position': 'view',
})

# %%
pd.concat([covid_df, nih_renamed_df], join='inner', ignore_index=True)
# Out:
#        patientid sex   age                   finding view
# 0              2   M  65.0  Pneumonia/Viral/COVID-19   PA
# 1              2   M  65.0  Pneumonia/Viral/COVID-19   PA
# 2              2   M  65.0  Pneumonia/Viral/COVID-19   PA
# 3              2   M  65.0  Pneumonia/Viral/COVID-19   PA
# 4              4   F  52.0  Pneumonia/Viral/COVID-19   PA
# ...          ...  ..   ...                       ...  ...
# 113065     30801   M  39.0            Mass|Pneumonia   PA
# 113066     30802   M  29.0                No Finding   PA
# 113067     30803   F  42.0                No Finding   PA
# 113068     30804   F  30.0                No Finding   PA
# 113069     30805   M  27.0                No Finding   PA
#
# [113070 rows x 5 columns]
