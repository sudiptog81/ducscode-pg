# %%
# %%capture
# !pip install pycaret==2.3.10 scikit-learn==0.23.2

# %%
# %%capture
# !pip install numpy==1.20

# %% [markdown]
# ## Importing Dataset

# %%
from pycaret.datasets import get_data
data = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# ## Setting up Dataset for PyCaret

# %%
from pycaret.classification import *
s = setup(data, target = 'Class variable')
# Out:
#                                Description             Value
# 0                               session_id              4974
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 23)
# 12                    Transformed Test Set         (231, 23)
# 13                      Shuffle Train-Test              True
# ...

# %% [markdown]
# ## Finding the Best Models for the Dataset

# %%
best = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7503  0.7989  0.5542  0.6998
# ridge                    Ridge Classifier    0.7466  0.0000  0.5445  0.6970
# rf               Random Forest Classifier    0.7447  0.8041  0.5695  0.6890
# lda          Linear Discriminant Analysis    0.7429  0.7956  0.5447  0.6934
# gbc          Gradient Boosting Classifier    0.7412  0.8033  0.6066  0.6698
# ada                  Ada Boost Classifier    0.7282  0.7927  0.6018  0.6431
# lightgbm  Light Gradient Boosting Machine    0.7112  0.7722  0.5755  0.6151
# et                 Extra Trees Classifier    0.7095  0.7519  0.4842  0.6455
# knn                K Neighbors Classifier    0.7020  0.7474  0.5661  0.6097
# dt               Decision Tree Classifier    0.6816  0.6560  0.5616  0.5726
# nb                            Naive Bayes    0.6613  0.7343  0.2247  0.5809
# ...

# %% [markdown]
# ## Creating Individual Tuned Models
#
# ```random_state=777```

# %%
import numpy as np
import pandas as pd
import seaborn as sea
import matplotlib.pyplot as plt

# %% [markdown]
# ### Logistic Regression

# %%
_lr = create_model('lr')
_lr_tuned = tune_model(_lr)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.6852  0.7549  0.3684  0.5833  0.4516  0.2463  0.2591
# 1       0.7963  0.8956  0.7000  0.7368  0.7179  0.5587  0.5591
# 2       0.7222  0.8456  0.5500  0.6471  0.5946  0.3854  0.3884
# 3       0.8704  0.8779  0.7500  0.8824  0.8108  0.7132  0.7187
# 4       0.7778  0.8294  0.6500  0.7222  0.6842  0.5135  0.5152
# 5       0.7222  0.7588  0.5000  0.6667  0.5714  0.3721  0.3805
# 6       0.7407  0.7647  0.6500  0.6500  0.6500  0.4441  0.4441
# 7       0.8113  0.8204  0.6316  0.8000  0.7059  0.5698  0.5784
# 8       0.6226  0.6889  0.4737  0.4737  0.4737  0.1796  0.1796
# 9       0.7170  0.8297  0.4211  0.6667  0.5161  0.3302  0.3477
# Mean    0.7466  0.8066  0.5695  0.6829  0.6176  0.4313  0.4371
# Std     0.0665  0.0603  0.1197  0.1070  0.1104  0.1534  0.1523
# INFO:logs:create_model_container: 16
# INFO:logs:master_model_container: 16
# INFO:logs:display_container: 4
# ...

# %%
_lr_tuned
# Out:
# LogisticRegression(C=5.844, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=777, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(_lr_tuned)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=LogisticRegression(C=5.844, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=777, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### AdaBoost

# %%
_ada = create_model('ada')
_ada_tuned = tune_model(_ada)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7222  0.7962  0.3684  0.7000  0.4828  0.3170  0.3476
# 1       0.7778  0.8706  0.7000  0.7000  0.7000  0.5235  0.5235
# 2       0.8148  0.8662  0.7500  0.7500  0.7500  0.6029  0.6029
# 3       0.8889  0.9574  0.8000  0.8889  0.8421  0.7568  0.7593
# 4       0.8333  0.9147  0.8000  0.7619  0.7805  0.6463  0.6468
# 5       0.7407  0.8147  0.5000  0.7143  0.5882  0.4075  0.4213
# 6       0.7593  0.8287  0.5500  0.7333  0.6286  0.4558  0.4661
# 7       0.7736  0.8073  0.5789  0.7333  0.6471  0.4838  0.4911
# 8       0.7170  0.7663  0.7895  0.5769  0.6667  0.4309  0.4470
# 9       0.7547  0.8676  0.5789  0.6875  0.6286  0.4475  0.4512
# Mean    0.7782  0.8490  0.6416  0.7246  0.6714  0.5072  0.5157
# Std     0.0508  0.0549  0.1408  0.0733  0.0974  0.1224  0.1155
# INFO:logs:create_model_container: 18
# INFO:logs:master_model_container: 18
# INFO:logs:display_container: 6
# ...

# %%
_ada_tuned
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.1,
#                    n_estimators=100, random_state=777)

# %%
evaluate_model(_ada_tuned)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=0.1,
#                    n_estimators=100, random_state=777), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Random Forest

# %%
_rf = create_model('rf')
_rf_tuned = tune_model(_rf)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.6852  0.8000  0.2105  0.6667  0.3200  0.1818  0.2331
# 1       0.7778  0.8574  0.6000  0.7500  0.6667  0.5031  0.5101
# 2       0.7963  0.8471  0.6000  0.8000  0.6857  0.5395  0.5518
# 3       0.8704  0.9647  0.7500  0.8824  0.8108  0.7132  0.7187
# 4       0.8148  0.8809  0.7500  0.7500  0.7500  0.6029  0.6029
# 5       0.7037  0.8353  0.4000  0.6667  0.5000  0.3077  0.3280
# 6       0.7778  0.8059  0.6000  0.7500  0.6667  0.5031  0.5101
# 7       0.7547  0.8297  0.5789  0.6875  0.6286  0.4475  0.4512
# 8       0.7170  0.7214  0.6316  0.6000  0.6154  0.3917  0.3921
# 9       0.7547  0.8591  0.6316  0.6667  0.6486  0.4605  0.4609
# Mean    0.7652  0.8401  0.5753  0.7220  0.6292  0.4651  0.4759
# Std     0.0525  0.0591  0.1526  0.0771  0.1290  0.1413  0.1311
# INFO:logs:create_model_container: 20
# INFO:logs:master_model_container: 20
# INFO:logs:display_container: 8
# ...

# %%
_rf_tuned
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight={},
#                        criterion='gini', max_depth=7, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0005, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=230,
#                        n_jobs=-1, oob_score=False, random_state=777, verbose=0,
#                        warm_start=False)

# %%
evaluate_model(_rf_tuned)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight={},
#                        criterion='gini', max_depth=7, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0005, min_impurity_split=None,
#                        min_samples_leaf=4, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=230,
#                        n_jobs=-1, oob_score=False, random_state=777, verbose=0,
#                        warm_start=False), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### KNN

# %%
_knn = create_model('knn')
_knn_tuned = tune_model(_knn)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.6852  0.8000  0.2632  0.6250  0.3704  0.2045  0.2385
# 1       0.7963  0.8941  0.6000  0.8000  0.6857  0.5395  0.5518
# 2       0.7593  0.7853  0.5500  0.7333  0.6286  0.4558  0.4661
# 3       0.8148  0.9147  0.6500  0.8125  0.7222  0.5859  0.5941
# 4       0.7963  0.8985  0.6500  0.7647  0.7027  0.5493  0.5535
# 5       0.6852  0.7941  0.4000  0.6154  0.4848  0.2726  0.2857
# 6       0.7222  0.7412  0.6000  0.6316  0.6154  0.3982  0.3985
# 7       0.7547  0.8297  0.6316  0.6667  0.6486  0.4605  0.4609
# 8       0.6604  0.6146  0.4737  0.5294  0.5000  0.2441  0.2449
# 9       0.7358  0.8065  0.5263  0.6667  0.5882  0.3977  0.4037
# Mean    0.7410  0.8079  0.5345  0.6845  0.5947  0.4108  0.4198
# Std     0.0502  0.0837  0.1185  0.0862  0.1059  0.1268  0.1231
# INFO:logs:create_model_container: 22
# INFO:logs:master_model_container: 22
# INFO:logs:display_container: 10
# ...

# %%
_knn_tuned
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='manhattan',
#                      metric_params=None, n_jobs=-1, n_neighbors=48, p=2,
#                      weights='distance')

# %%
evaluate_model(_knn_tuned)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='manhattan',
#                      metric_params=None, n_jobs=-1, n_neighbors=48, p=2,
#                      weights='distance'), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Decision Tree

# %%
_dt = create_model('dt')
_dt_tuned = tune_model(_dt)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.7037  0.7346  0.4211  0.6154  0.5000  0.2998  0.3107
# 1       0.7778  0.8507  0.6500  0.7222  0.6842  0.5135  0.5152
# 2       0.7593  0.8331  0.6500  0.6842  0.6667  0.4785  0.4788
# 3       0.8333  0.8934  0.7500  0.7895  0.7692  0.6389  0.6394
# 4       0.8148  0.8772  0.8500  0.7083  0.7727  0.6186  0.6260
# 5       0.7037  0.7735  0.5000  0.6250  0.5556  0.3374  0.3421
# 6       0.7222  0.6868  0.6000  0.6316  0.6154  0.3982  0.3985
# 7       0.7547  0.7678  0.5789  0.6875  0.6286  0.4475  0.4512
# 8       0.5660  0.6354  0.5263  0.4167  0.4651  0.1083  0.1104
# 9       0.7170  0.7794  0.7368  0.5833  0.6512  0.4184  0.4265
# Mean    0.7353  0.7832  0.6263  0.6464  0.6309  0.4259  0.4299
# Std     0.0706  0.0787  0.1224  0.0957  0.0971  0.1479  0.1475
# INFO:logs:create_model_container: 24
# INFO:logs:master_model_container: 24
# INFO:logs:display_container: 12
# ...

# %%
_dt_tuned
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.005, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=777, splitter='best')

# %%
evaluate_model(_dt_tuned)
# Out:
# INFO:logs:Initializing evaluate_model()
# INFO:logs:evaluate_model(estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=4, max_features=1.0, max_leaf_nodes=None,
#                        min_impurity_decrease=0.005, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=777, splitter='best'), fold=None, fit_kwargs=None, plot_kwargs=None, feature_name=None, groups=None, use_train_data=False)
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ## Creating an Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split

X = data.drop(['Class variable'], axis=1)
Y = data['Class variable']

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    Y,
                                                    test_size = 0.30,
                                                    random_state = 42)

# %%
vc = VotingClassifier(estimators=[('lr', _lr_tuned), ('dt', _dt_tuned), ('knn', _knn_tuned), ('rf', _rf_tuned), ('ada', _ada_tuned)], voting='soft')
vc.fit(X_train.values, y_train)
# Out:
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=5.844, class_weight={},
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=1000,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=777,
#                                                  solver='lbfgs', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('dt',
#                               DecisionTreeClassifier(ccp_alpha=0.0,
#                                                      class_weight=None,
#                                                      criterion='gini',...
# ...

# %%
from sklearn.metrics import classification_report

y_pred = vc.predict(X_test.values)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       151
#            1       0.67      0.61      0.64        80
#
#     accuracy                           0.76       231
#    macro avg       0.74      0.73      0.73       231
# weighted avg       0.76      0.76      0.76       231

# %% [markdown]
# ## Compare Everything

# %%
data = {
    'lr': 0.7466,
    'dt': 0.7353,
    'knn': 0.7410,
    'rf': 0.7652,
    'ada': 0.7782,
    'ensemble': 0.76
}

fig = plt.figure(figsize = (10, 5))

plt.bar(data.keys(), data.values())

plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.show()
